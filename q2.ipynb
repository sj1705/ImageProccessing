# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mat_img

# %%
def ChSwap(r, g, b):
    return Image.merge("RGB", (b, r, g))

# %%
img_1 = Image.open(r"RGBNinja.jpg")
img_1.show()

# %%
r, g, b = img_1.split()
new_rgb = ChSwap(r, g, b)
new_rgb.show()
new_rgb.save('ModifiedCreatedImages\RGBSwapNinja.png', 'PNG')

# %%
img_2 = mat_img.imread('ModifiedCreatedImages\RGBSwap.png')
f = plt.figure()
f.add_subplot(1,2, 1)
plt.imshow(img_1)
f.add_subplot(1,2, 2)
plt.imshow(img_2)
